# %%
import pandas as pd
import numpy as np
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\Nicole Macauley\Desktop\Projects In Progress\yield_df.csv")
data
# Out:
#        Unnamed: 0      Area            Item  Year  hg/ha_yield  \
# 0               0   Albania           Maize  1990        36613
# 1               1   Albania        Potatoes  1990        66667
# 2               2   Albania     Rice, paddy  1990        23333
# 3               3   Albania         Sorghum  1990        12500
# 4               4   Albania        Soybeans  1990         7000
# ...           ...       ...             ...   ...          ...
# 28237       28237  Zimbabwe     Rice, paddy  2013        22581
# 28238       28238  Zimbabwe         Sorghum  2013         3066
# 28239       28239  Zimbabwe        Soybeans  2013        13142
# 28240       28240  Zimbabwe  Sweet potatoes  2013        22222
# 28241       28241  Zimbabwe           Wheat  2013        22888
#
#        average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 0                             1485.0             121.00     16.37
# 1                             1485.0             121.00     16.37
# ...

# %%
# Lets check the columns name in the data
data.columns
# Out:
# Index(['Unnamed: 0', 'Area', 'Item', 'Year', 'hg/ha_yield',
#        'average_rain_fall_mm_per_year', 'pesticides_tonnes', 'avg_temp'],
#       dtype='object')

# %%
# Lets check the Unique values present in the Data
data.nunique()
# Out:
# Unnamed: 0                       28242
# Area                               101
# Item                                10
# Year                                23
# hg/ha_yield                      11514
# average_rain_fall_mm_per_year      100
# pesticides_tonnes                 1673
# avg_temp                          1831
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Started by sampling our data to have a good view of it.
data.sample(20)
# Out:
#        Unnamed: 0          Area            Item  Year  hg/ha_yield  \
# 12806       12806         India         Cassava  2004       270436
# 9691         9691        Guinea     Rice, paddy  1991        17110
# 1               1       Albania        Potatoes  1990        66667
# 10915       10915         India        Potatoes  1992       160294
# 18035       18035     Lithuania        Potatoes  2006        79083
# 22389       22389      Pakistan           Wheat  2000        24907
# 7717         7717       Ecuador         Sorghum  1999        13548
# 10443       10443       Hungary        Potatoes  2004       253210
# 5128         5128  Burkina Faso     Rice, paddy  2012        23336
# 23363       23363          Peru        Soybeans  1995        14416
# 1856         1856       Austria        Potatoes  2011       357127
# 22658       22658      Pakistan        Potatoes  2006       133447
# 6710         6710      Colombia     Rice, paddy  2000        47324
# ...

# %% [markdown]
# #  Data Structure

# %%
# Let's check for the data structure
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28242 entries, 0 to 28241
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     28242 non-null  int64
#  1   Area                           28242 non-null  object
#  2   Item                           28242 non-null  object
#  3   Year                           28242 non-null  int64
#  4   hg/ha_yield                    28242 non-null  int64
#  5   average_rain_fall_mm_per_year  28242 non-null  float64
#  6   pesticides_tonnes              28242 non-null  float64
#  7   avg_temp                       28242 non-null  float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 1.7+ MB

# %%
# Observation:
In this Dataset there are 2 columns (Entity) which have object Datatype
Three(3) columns is of int Datatype
Other 3 columns have Float Datatype

# %% [markdown]
# # Data Shape

# %%
# Let's check for the data shape
data.shape
# Out:
# (28242, 8)

# %%
Number of rows in the Data: 28242
number of columns in Data: 8

# %% [markdown]
# # Missing and Null Values

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# Unnamed: 0                       0
# Area                             0
# Item                             0
# Year                             0
# hg/ha_yield                      0
# average_rain_fall_mm_per_year    0
# pesticides_tonnes                0
# avg_temp                         0
# dtype: int64

# %%
# Inference:
# There is no Missing value Present in The Dataset

# %% [markdown]
# # A Summary Indicating The Distribution Of Key Agricultural Variables.

# %%
data.describe()
# Out:
#          Unnamed: 0          Year    hg/ha_yield  \
# count  28242.000000  28242.000000   28242.000000
# mean   14120.500000   2001.544296   77053.332094
# std     8152.907488      7.051905   84956.612897
# min        0.000000   1990.000000      50.000000
# 25%     7060.250000   1995.000000   19919.250000
# 50%    14120.500000   2001.000000   38295.000000
# 75%    21180.750000   2008.000000  104676.750000
# max    28241.000000   2013.000000  501412.000000
#
#        average_rain_fall_mm_per_year  pesticides_tonnes      avg_temp
# count                    28242.00000       28242.000000  28242.000000
# mean                      1149.05598       37076.909344     20.542627
# std                        709.81215       59958.784665      6.312051
# min                         51.00000           0.040000      1.300000
# 25%                        593.00000        1702.000000     16.702500
# 50%                       1083.00000       17529.440000     21.510000
# ...

# %% [markdown]
# # Renaming our Column Headers

# %%
data.rename(columns = {"hg/ha_yield": "Yield_Ton/Hectare", "average_rain_fall_mm_per_year": "Rainfall_mm", "pesticides_tonnes": "Pesticides_Tonnes",
                      "avg_temp": "Average_Temp"}, inplace =True)

# %%
data
# Out:
#            Area            Item  Year  Yield_Ton/Hectare  Rainfall_mm  \
# 0       Albania           Maize  1990              36613       1485.0
# 1       Albania        Potatoes  1990              66667       1485.0
# 2       Albania     Rice, paddy  1990              23333       1485.0
# 3       Albania         Sorghum  1990              12500       1485.0
# 4       Albania        Soybeans  1990               7000       1485.0
# ...         ...             ...   ...                ...          ...
# 28237  Zimbabwe     Rice, paddy  2013              22581        657.0
# 28238  Zimbabwe         Sorghum  2013               3066        657.0
# 28239  Zimbabwe        Soybeans  2013              13142        657.0
# 28240  Zimbabwe  Sweet potatoes  2013              22222        657.0
# 28241  Zimbabwe           Wheat  2013              22888        657.0
#
#        Pesticides_Tonnes  Average_Temp
# 0                 121.00         16.37
# 1                 121.00         16.37
# ...

# %% [markdown]
# # Standardize Crop Names By Removing References

# %%
data.rename(columns = {"Item": "Crop"}, inplace = True)

# %%
data["Crop"] = data["Crop"].apply(lambda x: x.replace(", paddy", " "))

# %%
data["Crop"] = data["Crop"].apply(lambda x: x.replace("and others", " "))

# %% [markdown]
# # Dropping Columns

# %%
data.drop(columns=['Unnamed: 0'], inplace = True)

# %%
data
# Out:
#            Area            Item  Year  hg/ha_yield  \
# 0       Albania           Maize  1990        36613
# 1       Albania        Potatoes  1990        66667
# 2       Albania     Rice, paddy  1990        23333
# 3       Albania         Sorghum  1990        12500
# 4       Albania        Soybeans  1990         7000
# ...         ...             ...   ...          ...
# 28237  Zimbabwe     Rice, paddy  2013        22581
# 28238  Zimbabwe         Sorghum  2013         3066
# 28239  Zimbabwe        Soybeans  2013        13142
# 28240  Zimbabwe  Sweet potatoes  2013        22222
# 28241  Zimbabwe           Wheat  2013        22888
#
#        average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 0                             1485.0             121.00     16.37
# 1                             1485.0             121.00     16.37
# 2                             1485.0             121.00     16.37
# 3                             1485.0             121.00     16.37
# ...

# %% [markdown]
# ###  So we are converting hg\ha yield to tonnes for easy analysis

# %%
data["Yield_Ton/Hectare"] = data["Yield_Ton/Hectare"] / 10000

# %%
data["Yield_Ton/Hectare"] = data["Yield_Ton/Hectare"].round(2)

# %%
data
# Out:
#            Area            Item  Year  Yield_Ton/Hectare  Rainfall_mm  \
# 0       Albania           Maize  1990               3.66       1485.0
# 1       Albania        Potatoes  1990               6.67       1485.0
# 2       Albania     Rice, paddy  1990               2.33       1485.0
# 3       Albania         Sorghum  1990               1.25       1485.0
# 4       Albania        Soybeans  1990               0.70       1485.0
# ...         ...             ...   ...                ...          ...
# 28237  Zimbabwe     Rice, paddy  2013               2.26        657.0
# 28238  Zimbabwe         Sorghum  2013               0.31        657.0
# 28239  Zimbabwe        Soybeans  2013               1.31        657.0
# 28240  Zimbabwe  Sweet potatoes  2013               2.22        657.0
# 28241  Zimbabwe           Wheat  2013               2.29        657.0
#
#        Pesticides_Tonnes  Average_Temp
# 0                 121.00         16.37
# 1                 121.00         16.37
# ...

# %% [markdown]
# Looking For Duplicate Values Present In Our Data

# %%
data.duplicated().sum()
# Out:
# 0

# %%
# We zero duplicate values in our data

# %% [markdown]
# Dropping Null Values

# %%
data.dropna()
# Out:
#            Area            Item  Year  hg/ha_yield  \
# 0       Albania           Maize  1990        36613
# 1       Albania        Potatoes  1990        66667
# 2       Albania     Rice, paddy  1990        23333
# 3       Albania         Sorghum  1990        12500
# 4       Albania        Soybeans  1990         7000
# ...         ...             ...   ...          ...
# 28237  Zimbabwe     Rice, paddy  2013        22581
# 28238  Zimbabwe         Sorghum  2013         3066
# 28239  Zimbabwe        Soybeans  2013        13142
# 28240  Zimbabwe  Sweet potatoes  2013        22222
# 28241  Zimbabwe           Wheat  2013        22888
#
#        average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 0                             1485.0             121.00     16.37
# 1                             1485.0             121.00     16.37
# 2                             1485.0             121.00     16.37
# 3                             1485.0             121.00     16.37
# ...

# %% [markdown]
# #  Observing Correlations Between Values

# %%
data_2  = data.corr(numeric_only=True)
data_2
# Out:
#                        Year  Yield_Ton/Hectare  Rainfall_mm  \
# Year               1.000000           0.091637    -0.003798
# Yield_Ton/Hectare  0.091637           1.000000     0.000961
# Rainfall_mm       -0.003798           0.000961     1.000000
# Pesticides_Tonnes  0.140930           0.064093     0.180984
# Average_Temp       0.014409          -0.114780     0.313040
#
#                    Pesticides_Tonnes  Average_Temp
# Year                        0.140930      0.014409
# Yield_Ton/Hectare           0.064093     -0.114780
# Rainfall_mm                 0.180984      0.313040
# Pesticides_Tonnes           1.000000      0.030946
# Average_Temp                0.030946      1.000000

# %%
plt.figure(figsize = (12, 6))
ax = sns.heatmap(data_2, annot=True)
ax
# Out:
# <Axes: >

# %%
data.reset_index(drop=True)
# Out:
#            Area            Item  Year  Yield_Ton/Hectare  Rainfall_mm  \
# 0       Albania           Maize  1990               3.66       1485.0
# 1       Albania        Potatoes  1990               6.67       1485.0
# 2       Albania     Rice, paddy  1990               2.33       1485.0
# 3       Albania         Sorghum  1990               1.25       1485.0
# 4       Albania        Soybeans  1990               0.70       1485.0
# ...         ...             ...   ...                ...          ...
# 28237  Zimbabwe     Rice, paddy  2013               2.26        657.0
# 28238  Zimbabwe         Sorghum  2013               0.31        657.0
# 28239  Zimbabwe        Soybeans  2013               1.31        657.0
# 28240  Zimbabwe  Sweet potatoes  2013               2.22        657.0
# 28241  Zimbabwe           Wheat  2013               2.29        657.0
#
#        Pesticides_Tonnes  Average_Temp
# 0                 121.00         16.37
# 1                 121.00         16.37
# ...

# %%
# Converting cleaned data to a csv file.

# %%
data.to_csv("Yields_df.csv", index=False)

# %%
data.sample(30)
# Out:
#                            Area            Crop  Year  Yield_Ton/Hectare  \
# 19925                    Mexico  Sweet potatoes  2005              21.49
# 3780                     Brazil         Sorghum  2002               1.86
# 6135   Central African Republic         Sorghum  1990               0.78
# 27568            United Kingdom           Wheat  1998               7.55
# 18783                Mauritania           Maize  2000               0.91
# 22448                  Pakistan  Sweet potatoes  2001              10.42
# 8054                    Ecuador         Cassava  2013               2.51
# 8316                      Egypt           Wheat  2007               6.47
# 390                   Argentina  Sweet potatoes  1990              13.19
# 21231               New Zealand           Wheat  1992               5.05
# 27353                    Uganda         Sorghum  2013               0.80
# 7943                    Ecuador           Wheat  2008               0.75
# ...
